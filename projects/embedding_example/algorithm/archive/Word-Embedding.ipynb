# %% [markdown]
# ### Importing required libraries and reading the file

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import re
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from scipy.spatial.distance import cdist
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import normalize
from wordcloud import WordCloud
from datetime import datetime
import random
from tqdm import tqdm
from gensim.models import Word2Vec

# %%
tlog = pd.read_csv(r"C:\Users\rtd91\Data\mlops\data\sample_tlog.csv")
product = pd.read_csv(r"C:\Users\rtd91\Data\mlops\data\sample_product.csv")
customer = pd.read_csv(r"C:\Users\rtd91\Data\mlops\data\sample_customer.csv")

# %%
def preprocessing(x):  
    ps = PorterStemmer()
    stop_words = set(stopwords.words('english')) 
    filtered_tokenized_text=[]
    tokenized_text = nltk.sent_tokenize(x)
    for sentence in tokenized_text:
        sentence = sentence.lower()
        word_tokens = word_tokenize(sentence)
        filtered_sentence = [ps.stem(w) for w in word_tokens if not w in stop_words]
        filtered_tokenized_text.append(filtered_sentence)
    return "".join([' '.join(text) for text in filtered_tokenized_text])

# %%
print(len(tlog["transaction_id"]),tlog["transaction_id"].nunique())
print(len(tlog["customer_id"]),tlog["customer_id"].nunique())
print(len(tlog["upc_no"]),tlog["upc_no"].nunique())
# Out:
# 595306 86108
# 595306 1243
# 595306 2938

# %%
print(len(product["upc_no"]),product["upc_no"].nunique())
# Out:
# 2938 2938

# %%
print(len(customer["customer_id"]),customer["customer_id"].nunique())
# Out:
# 1243 1243

# %%
product.head()
# Out:
#    Unnamed: 0      upc_no                   upc_desc  category_no_level_1  \
# 0           0  4600028876  OEP MLD TACO SEASONING MX                 2053
# 1           1  5210003491  MCCO ORIG TACO SEASNG MIX                 2053
# 2           2  2100003934  TACOBL ORIG TACO SSNG MIX                 2053
# 3           3  1111071507   KRO FAJITA SEASONING MIX                 2053
# 4           4  1111071503  KRO REG TACO SEASONING MX                 2053
#
#      category_desc_level_1  category_no_level_2      category_desc_level_2
# 0  MEXICAN SEASONING MIXES                   93  TRADITIONAL MEXICAN FOODS
# 1  MEXICAN SEASONING MIXES                   93  TRADITIONAL MEXICAN FOODS
# 2  MEXICAN SEASONING MIXES                   93  TRADITIONAL MEXICAN FOODS
# 3  MEXICAN SEASONING MIXES                   93  TRADITIONAL MEXICAN FOODS
# 4  MEXICAN SEASONING MIXES                   93  TRADITIONAL MEXICAN FOODS

# %%
customer.head()
# Out:
#    Unnamed: 0  customer_id convenience_dim_seg quality_dim_seg health_dim_seg  \
# 0           0     60622933                   M               M              M
# 1           1    116318566                   M               L              M
# 2           2    290772182                   M               M              M
# 3           3     97514036                   M               M              M
# 4           4    346208265                   H               M              L
#
#   price_dim_seg  convenience_dim_score  quality_dim_score  health_dim_score  \
# 0             M              57.237420          58.455336         46.045199
# 1             M              55.043287          36.847263         49.923244
# 2             H              51.416044          46.398561         48.046043
# 3             M              53.418191          57.848860         51.320066
# 4             M              59.661310          57.548050         48.700522
#
#    price_dim_score
# 0        56.256278
# 1        57.525922
# 2        66.436402
# 3        62.298526
# 4        62.308051

# %%
tlog.head()
# Out:
#    Unnamed: 0                      transaction_id  customer_id  upc_no  \
# 0           0   014_00817_4_121_20190313_18:04:00     14595593   94011
# 1           1    014_00817_3_81_20190417_14:57:00     14595593   94011
# 2           2    014_00817_3_67_20190927_12:51:00     14595593   94011
# 3           3    014_00380_7_68_20190315_13:18:00    238487018   94011
# 4           4  014_00811_525_68_20200131_11:53:00    300620568   94011
#
#    category_no_level_1  trans_dt   week_no  store_id  region_cd  \
# 0                62002  20190313  20190202       817         14
# 1                62002  20190417  20190303       817         14
# 2                62002  20190927  20190902       817         14
# 3                62002  20190315  20190202       380         14
# 4                62002  20200131  20191304       811         14
#
#    purchase_unit  sales_amt  disc_amt  purchase_price
# 0              1       1.90       0.0            1.90
# 1              1       1.53       0.0            1.53
# 2              1       2.03       0.0            2.03
# 3              1       2.02       0.0            2.02
# 4              1       1.96       0.0            1.96

# %% [markdown]
# ### Combine the transactions with products

# %%
tlog = pd.merge(tlog, product[["upc_no","upc_desc"]], on='upc_no', how='inner')
tlog
# Out:
#         Unnamed: 0                      transaction_id  customer_id  \
# 0                0   014_00817_4_121_20190313_18:04:00     14595593
# 1                1    014_00817_3_81_20190417_14:57:00     14595593
# 2                2    014_00817_3_67_20190927_12:51:00     14595593
# 3                3    014_00380_7_68_20190315_13:18:00    238487018
# 4                4  014_00811_525_68_20200131_11:53:00    300620568
# ...            ...                                 ...          ...
# 595301      595301  014_00466_17_131_20190630_13:39:00    330734391
# 595302      595302  014_00466_10_159_20191006_20:06:00    330734391
# 595303      595303  014_00448_503_43_20190605_08:57:00    116192279
# 595304      595304  014_00355_510_82_20190821_13:54:00    272781162
# 595305      595305   014_00825_16_54_20191014_11:05:00    147984026
#
#              upc_no  category_no_level_1  trans_dt   week_no  store_id  \
# 0             94011                62002  20190313  20190202       817
# 1             94011                62002  20190417  20190303       817
# 2             94011                62002  20190927  20190902       817
# 3             94011                62002  20190315  20190202       380
# 4             94011                62002  20200131  20191304       811
# ...             ...                  ...       ...       ...       ...
# 595301  20799300000                52201  20190630  20190602       466
# 595302  20799300000                52201  20191006  20190904       466
# 595303  20799300000                52201  20190605  20190502       448
# 595304  20799300000                52201  20190821  20190801       355
# 595305  20799300000                52201  20191014  20191001       825
#
#         region_cd  purchase_unit  sales_amt  disc_amt  purchase_price  \
# 0              14              1       1.90      0.00          1.9000
# 1              14              1       1.53      0.00          1.5300
# 2              14              1       2.03      0.00          2.0300
# 3              14              1       2.02      0.00          2.0200
# 4              14              1       1.96      0.00          1.9600
# ...           ...            ...        ...       ...             ...
# 595301         14              1      20.22      0.00         20.2200
# 595302         14              2      38.09      0.00         19.0450
# 595303         14              1      11.96      6.43         11.9600
# 595304         14              1       9.66      0.00          9.6600
# 595305         14              4      53.39     17.92         13.3475
#
#                         upc_desc
# 0       DOLE BANANAS TAPED ORGNC
# 1       DOLE BANANAS TAPED ORGNC
# 2       DOLE BANANAS TAPED ORGNC
# 3       DOLE BANANAS TAPED ORGNC
# 4       DOLE BANANAS TAPED ORGNC
# ...                          ...
# 595301        PK BUTT SR 1PC COV
# 595302        PK BUTT SR 1PC COV
# 595303        PK BUTT SR 1PC COV
# 595304        PK BUTT SR 1PC COV
# 595305        PK BUTT SR 1PC COV
#
# [595306 rows x 14 columns]

# %% [markdown]
# ### Cleaning date column

# %%
for i in range(len(tlog["week_no"])):
    tlog["week_no"][i] = str(tlog["week_no"][i])#[:4]+"-"+tlog["week_no"].astype(str)[4:6]+"-" + tlog["week_no"][i].astype(str)[6:8]
# Out:
# C:\Users\rtd91\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
tlog["week_no"] = tlog["week_no"].apply(lambda x:str(x))
tlog["week_no"] = tlog["week_no"].apply(lambda x: x[:4]+"-"+x[4:6]+"-"+x[6:8])

# %%
tlog["week_no"] = tlog["week_no"].apply(lambda x: datetime.strptime(x,"%Y-%d-%m"))

# %%
results = tlog.groupby(["customer_id","week_no"])["upc_desc"].apply(list)

# %%
len(results)
# Out:
# 38391

# %%
res1= pd.DataFrame(results)

# %%
res1
# Out:
#                                                                  upc_desc
# customer_id week_no
# 2715888     2019-04-04  [SPKLN ICE CHERRY LIMEADE, KRO APPLES HNYCRISP...
# 7420205     2019-01-01  [SNYDR FF MINI PRETZELS, SNYDR NBLRS SOURDOUGH...
#             2019-01-02  [HTGF CHK ENHC BRST BLSL, LETTUCE BOSTON RPC, ...
#             2019-01-04  [PHLLY CREAM CHS BAR 2CT, BROCCOLI CROWNS, PRS...
#             2019-01-05  [DRIS STRAWBERRIES PREM, HEINZ TOMATO KETCHUP,...
# ...                                                                   ...
# 1881300090  2019-04-13                        [HRSHY MILK CHOCOLATE BARS]
# 1975400030  2019-02-09                           [KROGER APPLE CIDER NFC]
#             2019-02-10  [NSTL SPLSH WILD BERRY 6PK, NSTL SPLSH LEMON 6...
#             2019-03-05              [GATORADE FRCE GRAPE, KRO 2% RF MILK]
#             2019-03-07  [GATORADE FRCE GRAPE, KRO KICK OF LIME TORT CH...
#
# [38391 rows x 1 columns]

# %% [markdown]
# ### Cleaning the dataframe according to our requirements

# %%
customer_id=[]
dates=[]
for i in range(len(res1.index)):
    customer_id.append(res1.index[i][0])
    dates.append(res1.index[i][1])

# %%
upc_desc = list(res1["upc_desc"])

# %%
df = pd.DataFrame({"customer_id":customer_id, "dates":dates, "upc_desc":upc_desc})

# %%
df["num_products"] = df["upc_desc"].apply(lambda x: len(x))

# %%
df["flag"] = 0
for i in range(len(df)):
    if ('SPKLN ICE CHERRY LIMEADE' in df["upc_desc"][i] and 'SPKLN ICE PEACH NECTARINE' in df["upc_desc"][i]):
        df["flag"][i] = 1
# Out:
# C:\Users\rtd91\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
test = df[df["flag"]==1]

# %%
df
# Out:
#        customer_id      dates  \
# 0          2715888 2019-04-04
# 1          7420205 2019-01-01
# 2          7420205 2019-01-02
# 3          7420205 2019-01-04
# 4          7420205 2019-01-05
# ...            ...        ...
# 38386   1881300090 2019-04-13
# 38387   1975400030 2019-02-09
# 38388   1975400030 2019-02-10
# 38389   1975400030 2019-03-05
# 38390   1975400030 2019-03-07
#
#                                                 upc_desc  num_products  flag
# 0      [SPKLN ICE CHERRY LIMEADE, KRO APPLES HNYCRISP...             4     1
# 1      [SNYDR FF MINI PRETZELS, SNYDR NBLRS SOURDOUGH...             4     0
# 2      [HTGF CHK ENHC BRST BLSL, LETTUCE BOSTON RPC, ...            26     0
# 3      [PHLLY CREAM CHS BAR 2CT, BROCCOLI CROWNS, PRS...            21     0
# 4      [DRIS STRAWBERRIES PREM, HEINZ TOMATO KETCHUP,...            30     0
# ...                                                  ...           ...   ...
# 38386                        [HRSHY MILK CHOCOLATE BARS]             1     0
# 38387                           [KROGER APPLE CIDER NFC]             1     0
# 38388  [NSTL SPLSH WILD BERRY 6PK, NSTL SPLSH LEMON 6...             3     0
# 38389              [GATORADE FRCE GRAPE, KRO 2% RF MILK]             2     0
# 38390  [GATORADE FRCE GRAPE, KRO KICK OF LIME TORT CH...             5     0
#
# [38391 rows x 5 columns]

# %%
#df.to_csv("C:/Users/rtd91/code/ml-deployment-coe/projects/embedding_example/data/test.csv")

# %%
df = pd.read_csv("C:/Users/rtd91/code/ml-deployment-coe/projects/embedding_example/data/test.csv")

# %%
"""def test_model(df):
    max_scores = [] #scores is the number of matches
    products_similarity = {} #customer:scores # inter customer with same customer #intra customer with another customer
    transaction_id=[]
    indice_max_val = []
    index1 = []
    for i in range(len(df)):
        index1.append(i)
        scores = []
        index2 = []
        for j in range(len(df)):
            ## This condition is so that the record of customer is not compared to the same record
            if i == j:
                j=j+1
                continue
            intra_match = 0
            inter_match = 0
                
            #print((set(df["upc_desc"][i]).intersection(set(df["upc_desc"][j]))))
            transaction_id.append(str(i)+"&"+"")
            scores.append((len(set(df["upc_desc"][i]).intersection(set(df["upc_desc"][j])))))
            index2.append(j)
        max_scores.append(max(scores))
        indice_max_val.append(scores.index(max_scores[i]))
        break
    return max_scores, index1, indice_max_val, set(df["upc_desc"][index1][0]) ^ set(df["upc_desc"][indice_max_val][0]) #returns non-intersection items"""

# %%
"""test_model(df.head(5))"""
# Out:
# ([0], [0], [0], set())

# %% [markdown]
# ## Converting the column according to model input requirements

# %%
df["upc_desc"] = df["upc_desc"].apply(lambda x: ','.join(x))

# %%
df["upc_desc"][0]
# Out:
# 'SPKLN ICE CHERRY LIMEADE,KRO APPLES HNYCRISP POUCH,SPKLN ICE BLACK CHERRY,SPKLN ICE PEACH NECTARINE'

# %% [markdown]
# ## Dividing the data into train and validation datasets

# %%
customers = df["customer_id"].unique().tolist()
random.shuffle(customers)

# extract 90% of customer ID's
customers_train = [customers[i] for i in range(round(0.9*len(customers)))]

# split data into train and validation set
train_df = df[df['customer_id'].isin(customers_train)]
validation_df = df[~df['customer_id'].isin(customers_train)]

# %%
# list to capture purchase history of the customers
purchases_train = []

# populate the list with the product codes
for i in tqdm(customers_train):
    temp = train_df[train_df["customer_id"] == i]["upc_desc"].tolist()
    purchases_train.append(temp)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1119/1119 [00:00<00:00, 1202.90it/s]

# %%
# list to capture purchase history of the customers
purchases_val = []

# populate the list with the product codes
for i in tqdm(validation_df['customer_id'].unique()):
    temp = validation_df[validation_df["customer_id"] == i]["upc_desc"].tolist()
    purchases_val.append(temp)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 124/124 [00:00<00:00, 1516.25it/s]

# %%
##Make the model more memory efficient
model.init_sims(replace=True)
# Out:
# C:\Users\rtd91\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).

# %%
print(model)
# Out:
# Word2Vec(vocab=69, vector_size=100, alpha=0.03)

# %%
words = list(model.wv.index_to_key)

# %%
words[1]
# Out:
# 'DOLE BANANAS'

# %% [markdown]
# %md
# ## We can just see 69 words here since the default min_count of gensim word2Vec is equal to 5 so only words occuring greater than or equal to 5 times are added in the vocab.
# Reference: https://stackoverflow.com/questions/56033651/words-missing-from-trained-word2vec-model-vocabulary

# %%
words
# Out:
# ['KRO 2% RF MILK',
#  'DOLE BANANAS',
#  'DELI SALAD BAR',
#  'KRO PURIFIED WATER 32PK',
#  'KRO VITAMIN D WHOLE MILK',
#  'BUD LIGHT 24PK CAN',
#  'MTN DEW',
#  'KRO GRD A LG EGGS RACK',
#  'STO 2%RF MILK',
#  'KRO PURIFIED WATER 24PK',
#  'KRO GRD A LRG EGGS RCK',
#  'WHITE CLAW 12 PK CAN',
#  'HMCTY ICE NUGGETS 7LB',
#  'COKE CLASSIC CONTOUR BTL',
#  'ICEBERG LETTUCE',
#  'BH BQT MINUET',
#  'MONSTER ENERGY',
#  'DELI CKN WHL RSTD BIRD H',
#  'BKRY SS DONUTS',
#  'DOLE BANANAS TAPED ORGNC',
#  'KRO 1% LF MILK',
#  'SAS GRAN SUGAR PLLT',
#  'KRO DISTILLED WATER',
#  'KRO 30 DR BTH TSS',
#  'DIET COKE 12PK',
#  'KRO 2%RF MILK',
#  'BH BQT HARMONY',
#  'ICE CRUSHED CUBED',
#  'KRO CIN REDS WATER',
#  'RED BULL ENERGY DRINK',
#  'KALE BUNCH RPC',
#  'POST HNY BNCH OAT W/ALMND',
#  'DERPRK SPRING WATER 24PK',
#  'BHAUS BQT DUET',
#  'DASANI PURE WATER 24PK',
#  'COKE ZERO',
#  'MILLER LITE 24PK CAN',
#  'KRO 1%LF MILK',
#  'KALE BUNCH RPC,KALE BUNCH RPC',
#  'SNCKRS BAR',
#  'KRO POTATOES IDAHO PREM',
#  'PICK SIX 6PK BTL',
#  'WRGLY EXTRA SPEARMINT GUM',
#  'DIET MTN DEW',
#  'PEPSI',
#  'KRO VITMN D WHL MILK',
#  'BFG VANILLA CLBRTN 6IN CK',
#  'DIET COKE 6PK',
#  'CTO BATH TISSUE',
#  'DIET COKE CONTOUR BTL',
#  'KRO TRAD YLW RND TORTILLA',
#  'KRO FF SKIM MILK',
#  'KRO HEAVY WHIPPING CREAM',
#  'DELI CKN FR SLF SRV 8P H',
#  'KRO LF CHOC MILK',
#  'DIET MTN DEW 12PK',
#  'ANGSFT BATH TISSUE DBL RL',
#  'WATERMELON RED SDLS BIN',
#  'KRO GNT 10RL PPR TWL ROLL',
#  'KITKAT CRISP WAFER',
#  'BHAUS ROSE BUNCH LS COLOR',
#  'COKE CLASSIC',
#  'COKE CLASSIC 12PK',
#  'ST PISTACHIOS TUBE',
#  'KRO ADORB MANDARN BAG RPC',
#  'HMCTY ICE NUGGETS 22LB',
#  'KRO SPRING WATER 24PK',
#  'ASPARAGUS STANDARD',
#  'SPCY CKN WNGS BI C']

# %%
products = train_df[["upc_desc"]]

# remove duplicates
products.drop_duplicates(inplace=True, subset='upc_desc', keep="last")

# create product-ID and product-description dictionary
#products_dict = products.groupby('upc_desc')['Description'].apply(list).to_dict()
# Out:
# C:\Users\rtd91\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
def test_model(customer_id=190462787):
    df_cust = df[df["customer_id"]==customer_id] ## for multiple customer , using .isin()
    df_cust_prod = df_cust.groupby('customer_id')["upc_desc"].apply(list)
    recommended_products = []
    ## Can add another outer for loop for multiple customer recommendation
    ## Finding the intersection of above 69 vocab products and the customer's bought products
    most_common_bought_products = set(words).intersection(set(df_cust_prod[customer_id]))
    for products in most_common_bought_products:
        recommended_products.append(model.wv.most_similar(products, topn=3))
    
    ## add 2 more conditions:
    ## first make recommended products unique and convert it into a set
    ## second check if recommended products already exists in df_cust_prod[customer_id])
    return recommended_products

# %%
test_model(190462787)
# Out:
# [[('KALE BUNCH RPC', 0.357295960187912),
#   ('POST HNY BNCH OAT W/ALMND', 0.35685306787490845),
#   ('DERPRK SPRING WATER 24PK', 0.33967921137809753)]]

# %% [markdown]
# ### For customer having no recommendations, we can use customer2vec model

# %%
for cust_id in customers:
    print(cust_id)
    print(test_model(cust_id))
# Out:
# 190462787
# [[('KALE BUNCH RPC', 0.357295960187912), ('POST HNY BNCH OAT W/ALMND', 0.35685306787490845), ('DERPRK SPRING WATER 24PK', 0.33967921137809753)]]
# 146867350
# []
# 299207048
# []
# 92267703
# []
# 308559012
# []
# 259401963
# [[('KRO PURIFIED WATER 32PK', 0.34293630719184875), ('KALE BUNCH RPC', 0.3079712688922882), ('DASANI PURE WATER 24PK', 0.3035476803779602)], [('KITKAT CRISP WAFER', 0.18309709429740906), ('DELI CKN FR SLF SRV 8P H', 0.1500629186630249), ('MILLER LITE 24PK CAN', 0.14767128229141235)]]
# 101025127
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 209964619
# []
# 101913708
# []
# 128062453
# []
# 110982127
# []
# 147488885
# []
# 299535125
# []
# 338169082
# [[('BUD LIGHT 24PK CAN', 0.4054492712020874), ('KALE BUNCH RPC', 0.3748836815357208), ('STO 2%RF MILK', 0.3745972514152527)], [('KRO PURIFIED WATER 24PK', 0.3870144486427307), ('DASANI PURE WATER 24PK', 0.3767983019351959), ('KALE BUNCH RPC', 0.3621307611465454)]]
# 296158912
# []
# 147039760
# []
# 221726793
# []
# 276732299
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.7494122385978699), ('STO 2%RF MILK', 0.728879988193512), ('KALE BUNCH RPC', 0.7271060943603516)]]
# 147272973
# []
# 64837115
# []
# 149163486
# [[('DIET COKE 12PK', 0.20309126377105713), ('BH BQT HARMONY', 0.17082688212394714), ('KRO VITAMIN D WHOLE MILK', 0.16518577933311462)]]
# 86927514
# []
# 147372691
# [[('KALE BUNCH RPC', 0.5240429639816284), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4924411177635193), ('BUD LIGHT 24PK CAN', 0.47190362215042114)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.9579091668128967), ('STO 2%RF MILK', 0.9059560894966125), ('BUD LIGHT 24PK CAN', 0.8698781728744507)], [('KALE BUNCH RPC', 0.9579091668128967), ('STO 2%RF MILK', 0.9135625958442688), ('BUD LIGHT 24PK CAN', 0.8689241409301758)]]
# 14991101
# []
# 108594632
# []
# 108002214
# []
# 292771463
# []
# 102088539
# []
# 339648969
# [[('KALE BUNCH RPC', 0.7111926078796387), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.6928669810295105), ('STO 2%RF MILK', 0.6835572719573975)], [('KALE BUNCH RPC', 0.4894072413444519), ('STO 2%RF MILK', 0.46752282977104187), ('BUD LIGHT 24PK CAN', 0.4584292471408844)]]
# 22018951
# []
# 104376680
# []
# 124513431
# [[('KRO HEAVY WHIPPING CREAM', 0.2864796817302704), ('STO 2%RF MILK', 0.2721879184246063), ('KALE BUNCH RPC', 0.26774534583091736)]]
# 317404544
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)], [('KRO HEAVY WHIPPING CREAM', 0.25994011759757996), ('BUD LIGHT 24PK CAN', 0.2513977885246277), ('DIET COKE 6PK', 0.21376897394657135)]]
# 125070079
# []
# 420100185
# []
# 123801689
# []
# 73625534
# []
# 325076029
# []
# 89907732
# []
# 146760216
# []
# 184571502
# []
# 194081576
# []
# 91236607
# []
# 101184843
# []
# 97877559
# []
# 192800009
# [[('COKE CLASSIC', 0.3199152648448944), ('STO 2%RF MILK', 0.31376686692237854), ('SAS GRAN SUGAR PLLT', 0.30172204971313477)], [('KALE BUNCH RPC', 0.5986707806587219), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.5664805173873901), ('BUD LIGHT 24PK CAN', 0.5379250049591064)]]
# 106066662
# []
# 227442770
# [[('ICE CRUSHED CUBED', 0.27641263604164124), ('COKE CLASSIC', 0.23531830310821533), ('CTO BATH TISSUE', 0.17823508381843567)]]
# 64906407
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 147973579
# []
# 145673785
# [[('KRO 2% RF MILK', 0.21689674258232117), ('KRO 1% LF MILK', 0.21043917536735535), ('COKE CLASSIC 12PK', 0.20376767218112946)]]
# 122591135
# [[('ICE CRUSHED CUBED', 0.3891516327857971), ('DOLE BANANAS TAPED ORGNC', 0.27235695719718933), ('ICEBERG LETTUCE', 0.24126875400543213)]]
# 195047631
# []
# 108722305
# []
# 146803470
# []
# 291521274
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.684607207775116), ('KALE BUNCH RPC', 0.6784859895706177), ('STO 2%RF MILK', 0.6488761305809021)]]
# 16051918
# []
# 147470700
# []
# 310047503
# []
# 251618695
# []
# 148019831
# []
# 96254537
# [[('KALE BUNCH RPC', 0.6344715356826782), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.6291137337684631), ('POST HNY BNCH OAT W/ALMND', 0.5791609883308411)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.7494122385978699), ('STO 2%RF MILK', 0.728879988193512), ('KALE BUNCH RPC', 0.7271060943603516)]]
# 156208298
# []
# 211788499
# []
# 148257003
# []
# 95627521
# [[('DIET COKE 12PK', 0.2996777892112732), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.2644175589084625), ('STO 2%RF MILK', 0.26067110896110535)]]
# 98659298
# []
# 260744167
# [[('ICE CRUSHED CUBED', 0.27641263604164124), ('COKE CLASSIC', 0.23531830310821533), ('CTO BATH TISSUE', 0.17823508381843567)]]
# 92158231
# []
# 193829304
# []
# 240867595
# [[('SNCKRS BAR', 0.20096398890018463), ('DERPRK SPRING WATER 24PK', 0.13142672181129456), ('KRO VITAMIN D WHOLE MILK', 0.1141682043671608)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 101434379
# []
# 244101466
# []
# 201976392
# []
# 147721895
# [[('KALE BUNCH RPC', 0.5168688297271729), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.5123421549797058), ('KRO PURIFIED WATER 32PK', 0.46817290782928467)]]
# 304444573
# [[('KRO HEAVY WHIPPING CREAM', 0.2864796817302704), ('STO 2%RF MILK', 0.2721879184246063), ('KALE BUNCH RPC', 0.26774534583091736)]]
# 321425106
# [[('KALE BUNCH RPC', 0.2934151291847229), ('STO 2%RF MILK', 0.28568035364151), ('HMCTY ICE NUGGETS 22LB', 0.2849181890487671)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 146821889
# []
# 149387859
# []
# 202284409
# [[('KALE BUNCH RPC', 0.5240429639816284), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4924411177635193), ('BUD LIGHT 24PK CAN', 0.47190362215042114)]]
# 128039089
# []
# 89364929
# [[('KRO 2% RF MILK', 0.21689674258232117), ('KRO 1% LF MILK', 0.21043917536735535), ('COKE CLASSIC 12PK', 0.20376767218112946)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 102447713
# []
# 84524527
# [[('KALE BUNCH RPC', 0.2934151291847229), ('STO 2%RF MILK', 0.28568035364151), ('HMCTY ICE NUGGETS 22LB', 0.2849181890487671)]]
# 220944291
# []
# 146843375
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 309637950
# []
# 43191105
# []
# 317404434
# [[('ICEBERG LETTUCE', 0.2603684663772583), ('DELI CKN FR SLF SRV 8P H', 0.25517693161964417), ('KRO 1%LF MILK', 0.21925628185272217)]]
# 147165959
# []
# 209904553
# []
# 220637800
# []
# 147457549
# [[('KRO HEAVY WHIPPING CREAM', 0.25994011759757996), ('BUD LIGHT 24PK CAN', 0.2513977885246277), ('DIET COKE 6PK', 0.21376897394657135)]]
# 97661139
# [[('SNCKRS BAR', 0.3891516327857971), ('CTO BATH TISSUE', 0.36832478642463684), ('KITKAT CRISP WAFER', 0.32578742504119873)], [('KRO PURIFIED WATER 24PK', 0.3870144486427307), ('DASANI PURE WATER 24PK', 0.3767983019351959), ('KALE BUNCH RPC', 0.3621307611465454)]]
# 272440857
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 160127352
# []
# 238176999
# []
# 221735060
# []
# 16013050
# [[('ICE CRUSHED CUBED', 0.27641263604164124), ('COKE CLASSIC', 0.23531830310821533), ('CTO BATH TISSUE', 0.17823508381843567)], [('SNCKRS BAR', 0.3891516327857971), ('CTO BATH TISSUE', 0.36832478642463684), ('KITKAT CRISP WAFER', 0.32578742504119873)]]
# 338891804
# []
# 164423380
# []
# 312840730
# [[('ICE CRUSHED CUBED', 0.3891516327857971), ('DOLE BANANAS TAPED ORGNC', 0.27235695719718933), ('ICEBERG LETTUCE', 0.24126875400543213)]]
# 320601041
# []
# 265096775
# []
# 101842798
# []
# 291901432
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 91777327
# []
# 146582229
# []
# 55954558
# []
# 260074774
# []
# 237312403
# []
# 270488234
# []
# 147882809
# []
# 222539855
# []
# 107284505
# []
# 320290460
# []
# 226681599
# [[('KRO PURIFIED WATER 32PK', 0.34293630719184875), ('KALE BUNCH RPC', 0.3079712688922882), ('DASANI PURE WATER 24PK', 0.3035476803779602)]]
# 324612854
# []
# 78129532
# []
# 68290976
# []
# 15422060
# []
# 189939317
# []
# 276732978
# []
# 251015585
# []
# 189346652
# []
# 148379946
# []
# 97633686
# []
# 17359853
# []
# 99947594
# [[('KRO 2% RF MILK', 0.21689674258232117), ('KRO 1% LF MILK', 0.21043917536735535), ('COKE CLASSIC 12PK', 0.20376767218112946)]]
# 319567419
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 90165728
# []
# 127848665
# []
# 96415729
# []
# 304751677
# []
# 196052179
# []
# 259077184
# []
# 105941434
# []
# 92422918
# []
# 127896724
# []
# 146602104
# []
# 272781162
# []
# 345003731
# []
# 14932934
# []
# 87508730
# []
# 147696422
# []
# 254814171
# [[('DOLE BANANAS TAPED ORGNC', 0.32175910472869873), ('BUD LIGHT 24PK CAN', 0.3027614653110504), ('KRO 30 DR BTH TSS', 0.29918035864830017)]]
# 15719401
# []
# 148122032
# []
# 148120838
# []
# 243126954
# []
# 102216134
# []
# 99540998
# [[('COKE CLASSIC', 0.4890950918197632), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4687293469905853), ('POST HNY BNCH OAT W/ALMND', 0.4420761466026306)]]
# 159644349
# []
# 105925221
# []
# 187033206
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)], [('KRO PURIFIED WATER 32PK', 0.2664624750614166), ('DIET COKE 12PK', 0.26443296670913696), ('BHAUS ROSE BUNCH LS COLOR', 0.24772271513938904)]]
# 247294894
# []
# 325506036
# []
# 1975400030
# []
# 230893289
# [[('BUD LIGHT 24PK CAN', 0.4942016303539276), ('KALE BUNCH RPC', 0.4596514105796814), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.45333313941955566)]]
# 75830477
# []
# 126055589
# [[('BUD LIGHT 24PK CAN', 0.5987051725387573), ('KALE BUNCH RPC', 0.5926470160484314), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.5899031162261963)]]
# 146749305
# []
# 103315366
# []
# 134503513
# []
# 216038677
# []
# 100033371
# []
# 107555554
# []
# 242227100
# []
# 77252100
# []
# 290761603
# [[('KRO 2% RF MILK', 0.21689674258232117), ('KRO 1% LF MILK', 0.21043917536735535), ('COKE CLASSIC 12PK', 0.20376767218112946)], [('BUD LIGHT 24PK CAN', 0.36111050844192505), ('KRO PURIFIED WATER 32PK', 0.3399185538291931), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.33530083298683167)]]
# 98671672
# []
# 147786932
# []
# 108857000
# []
# 12666723
# []
# 223791875
# []
# 329473366
# [[('KALE BUNCH RPC', 0.8698782920837402), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.8689242601394653), ('STO 2%RF MILK', 0.812996506690979)]]
# 102019178
# []
# 148181429
# []
# 269310107
# []
# 233592881
# []
# 147723099
# []
# 127017317
# []
# 100315036
# [[('HMCTY ICE NUGGETS 22LB', 0.22136758267879486), ('PEPSI', 0.1876983493566513), ('BKRY SS DONUTS', 0.1681305170059204)]]
# 147871648
# []
# 102279589
# []
# 334639058
# []
# 146913527
# []
# 325962500
# []
# 299161612
# []
# 186220133
# [[('KALE BUNCH RPC', 0.46025264263153076), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4376057982444763), ('STO 2%RF MILK', 0.4360925257205963)], [('BKRY SS DONUTS', 0.28376561403274536), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.25741779804229736), ('KRO PURIFIED WATER 32PK', 0.2542024850845337)]]
# 120754208
# [[('COKE CLASSIC', 0.4890950918197632), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4687293469905853), ('POST HNY BNCH OAT W/ALMND', 0.4420761466026306)]]
# 89536549
# [[('HMCTY ICE NUGGETS 22LB', 0.22136758267879486), ('PEPSI', 0.1876983493566513), ('BKRY SS DONUTS', 0.1681305170059204)], [('DELI SALAD BAR', 0.2921435832977295), ('KALE BUNCH RPC', 0.28445255756378174), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.27370527386665344)]]
# 262536475
# []
# 123300592
# []
# 148153509
# [[('COKE CLASSIC', 0.4890950918197632), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4687293469905853), ('POST HNY BNCH OAT W/ALMND', 0.4420761466026306)]]
# 13245524
# []
# 148559805
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)], [('KALE BUNCH RPC', 0.28890085220336914), ('MILLER LITE 24PK CAN', 0.2722713351249695), ('KRO 1% LF MILK', 0.2714674472808838)], [('KALE BUNCH RPC', 0.6344715356826782), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.6291137337684631), ('POST HNY BNCH OAT W/ALMND', 0.5791609883308411)]]
# 147902496
# []
# 172515217
# [[('KALE BUNCH RPC', 0.7184330224990845), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.7033437490463257), ('STO 2%RF MILK', 0.6746741533279419)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.9579091668128967), ('STO 2%RF MILK', 0.9059560894966125), ('BUD LIGHT 24PK CAN', 0.8698781728744507)]]
# 169500349
# []
# 127285290
# [[('KRO PURIFIED WATER 32PK', 0.34293630719184875), ('KALE BUNCH RPC', 0.3079712688922882), ('DASANI PURE WATER 24PK', 0.3035476803779602)], [('KRO PURIFIED WATER 32PK', 0.2664624750614166), ('DIET COKE 12PK', 0.26443296670913696), ('BHAUS ROSE BUNCH LS COLOR', 0.24772271513938904)]]
# 146574957
# [[('KALE BUNCH RPC', 0.7184330224990845), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.7033437490463257), ('STO 2%RF MILK', 0.6746741533279419)], [('COKE ZERO', 0.43542152643203735), ('STO 2%RF MILK', 0.3702376186847687), ('DASANI PURE WATER 24PK', 0.34250926971435547)]]
# 201388932
# [[('KRO HEAVY WHIPPING CREAM', 0.25994011759757996), ('BUD LIGHT 24PK CAN', 0.2513977885246277), ('DIET COKE 6PK', 0.21376897394657135)]]
# 93821961
# []
# 129439290
# [[('KALE BUNCH RPC', 0.5168688297271729), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.5123421549797058), ('KRO PURIFIED WATER 32PK', 0.46817290782928467)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.4988705515861511), ('BUD LIGHT 24PK CAN', 0.4734945595264435), ('STO 2%RF MILK', 0.4587148129940033)], [('KALE BUNCH RPC', 0.6249558329582214), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.6147710680961609), ('STO 2%RF MILK', 0.5822712182998657)]]
# 149358978
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 118743542
# []
# 234226093
# []
# 149405324
# []
# 89132255
# []
# 13375104
# []
# 287156086
# []
# 317050252
# []
# 148169938
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 95939714
# [[('KALE BUNCH RPC', 0.7111926078796387), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.6928669810295105), ('STO 2%RF MILK', 0.6835572719573975)]]
# 300634599
# [[('KITKAT CRISP WAFER', 0.18309709429740906), ('DELI CKN FR SLF SRV 8P H', 0.1500629186630249), ('MILLER LITE 24PK CAN', 0.14767128229141235)], [('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 101246819
# [[('BUD LIGHT 24PK CAN', 0.4942016303539276), ('KALE BUNCH RPC', 0.4596514105796814), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.45333313941955566)], [('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)], [('KALE BUNCH RPC', 0.4285537898540497), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.3826340436935425), ('STO 2%RF MILK', 0.35212093591690063)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 324196219
# []
# 129677989
# [[('KRO 2% RF MILK', 0.2402542680501938), ('KRO POTATOES IDAHO PREM', 0.2196442186832428), ('KRO PURIFIED WATER 24PK', 0.21184732019901276)]]
# 16190013
# []
# 147060478
# []
# 148037354
# [[('KRO PURIFIED WATER 32PK', 0.2664624750614166), ('DIET COKE 12PK', 0.26443296670913696), ('BHAUS ROSE BUNCH LS COLOR', 0.24772271513938904)]]
# 148137996
# []
# 330765567
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.7494122385978699), ('STO 2%RF MILK', 0.728879988193512), ('KALE BUNCH RPC', 0.7271060943603516)], [('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 338117000
# []
# 266402922
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.36689767241477966), ('KALE BUNCH RPC', 0.34272706508636475), ('STO 2%RF MILK', 0.3406410813331604)]]
# 193572768
# []
# 271434453
# [[('KRO 1% LF MILK', 0.2506715655326843), ('COKE CLASSIC', 0.2387664020061493), ('BUD LIGHT 24PK CAN', 0.2380378693342209)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 527500125
# [[('DIET MTN DEW 12PK', 0.22819821536540985), ('DOLE BANANAS', 0.19578896462917328), ('KRO GNT 10RL PPR TWL ROLL', 0.1876983493566513)], [('KALE BUNCH RPC', 0.7184330224990845), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.7033437490463257), ('STO 2%RF MILK', 0.6746741533279419)]]
# 174871533
# []
# 147717148
# [[('KALE BUNCH RPC', 0.4285537898540497), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.3826340436935425), ('STO 2%RF MILK', 0.35212093591690063)]]
# 149306175
# []
# 123212424
# [[('KRO 2% RF MILK', 0.21689674258232117), ('KRO 1% LF MILK', 0.21043917536735535), ('COKE CLASSIC 12PK', 0.20376767218112946)], [('DIET COKE 12PK', 0.2996777892112732), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.2644175589084625), ('STO 2%RF MILK', 0.26067110896110535)]]
# 108796838
# [[('KALE BUNCH RPC', 0.46195340156555176), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.45312488079071045), ('STO 2%RF MILK', 0.4478839635848999)]]
# 148663992
# []
# 149427950
# []
# 146774056
# []
# 326329135
# []
# 23461592
# [[('KRO PURIFIED WATER 32PK', 0.34293630719184875), ('KALE BUNCH RPC', 0.3079712688922882), ('DASANI PURE WATER 24PK', 0.3035476803779602)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.684607207775116), ('KALE BUNCH RPC', 0.6784859895706177), ('STO 2%RF MILK', 0.6488761305809021)]]
# 146536012
# [[('BUD LIGHT 24PK CAN', 0.36111050844192505), ('KRO PURIFIED WATER 32PK', 0.3399185538291931), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.33530083298683167)]]
# 92913514
# [[('KALE BUNCH RPC', 0.46025264263153076), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4376057982444763), ('STO 2%RF MILK', 0.4360925257205963)]]
# 332004375
# [[('KALE BUNCH RPC', 0.7111926078796387), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.6928669810295105), ('STO 2%RF MILK', 0.6835572719573975)]]
# 258298604
# []
# 214803476
# []
# 43263159
# []
# 338172270
# [[('KRO PURIFIED WATER 32PK', 0.34293630719184875), ('KALE BUNCH RPC', 0.3079712688922882), ('DASANI PURE WATER 24PK', 0.3035476803779602)]]
# 106380458
# []
# 303627301
# [[('DIET COKE 12PK', 0.48909515142440796), ('BUD LIGHT 24PK CAN', 0.4245010018348694), ('KALE BUNCH RPC', 0.4238097667694092)], [('SNCKRS BAR', 0.20096398890018463), ('DERPRK SPRING WATER 24PK', 0.13142672181129456), ('KRO VITAMIN D WHOLE MILK', 0.1141682043671608)]]
# 146782840
# []
# 92742297
# [[('KALE BUNCH RPC', 0.2934151291847229), ('STO 2%RF MILK', 0.28568035364151), ('HMCTY ICE NUGGETS 22LB', 0.2849181890487671)]]
# 332464380
# []
# 292236289
# [[('COKE ZERO', 0.43542152643203735), ('STO 2%RF MILK', 0.3702376186847687), ('DASANI PURE WATER 24PK', 0.34250926971435547)]]
# 84020683
# [[('KRO 2% RF MILK', 0.1717262864112854), ('BFG VANILLA CLBRTN 6IN CK', 0.16423571109771729), ('KRO PURIFIED WATER 32PK', 0.15669207274913788)]]
# 15225733
# [[('KRO HEAVY WHIPPING CREAM', 0.25994011759757996), ('BUD LIGHT 24PK CAN', 0.2513977885246277), ('DIET COKE 6PK', 0.21376897394657135)]]
# 99357742
# []
# 341202491
# [[('ICEBERG LETTUCE', 0.2603684663772583), ('DELI CKN FR SLF SRV 8P H', 0.25517693161964417), ('KRO 1%LF MILK', 0.21925628185272217)]]
# 183661033
# [[('BUD LIGHT 24PK CAN', 0.4942016303539276), ('KALE BUNCH RPC', 0.4596514105796814), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.45333313941955566)]]
# 244935154
# [[('KRO HEAVY WHIPPING CREAM', 0.25994011759757996), ('BUD LIGHT 24PK CAN', 0.2513977885246277), ('DIET COKE 6PK', 0.21376897394657135)]]
# 92666424
# []
# 87470635
# []
# 342350374
# [[('KALE BUNCH RPC', 0.45346736907958984), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.447645902633667), ('DERPRK SPRING WATER 24PK', 0.423600435256958)]]
# 147681015
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 337788637
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)], [('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)], [('ICE CRUSHED CUBED', 0.3891516327857971), ('DOLE BANANAS TAPED ORGNC', 0.27235695719718933), ('ICEBERG LETTUCE', 0.24126875400543213)]]
# 238487895
# []
# 294143663
# []
# 248441463
# [[('KRO 2% RF MILK', 0.1717262864112854), ('BFG VANILLA CLBRTN 6IN CK', 0.16423571109771729), ('KRO PURIFIED WATER 32PK', 0.15669207274913788)]]
# 160925328
# [[('KRO PURIFIED WATER 24PK', 0.3870144486427307), ('DASANI PURE WATER 24PK', 0.3767983019351959), ('KALE BUNCH RPC', 0.3621307611465454)]]
# 291511244
# []
# 334639017
# [[('KALE BUNCH RPC', 0.6344715356826782), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.6291137337684631), ('POST HNY BNCH OAT W/ALMND', 0.5791609883308411)]]
# 146761570
# []
# 92015359
# []
# 339823136
# []
# 148128772
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)], [('BUD LIGHT 24PK CAN', 0.4942016303539276), ('KALE BUNCH RPC', 0.4596514105796814), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.45333313941955566)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 89496220
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 224049130
# []
# 234214430
# []
# 100870102
# [[('KRO PURIFIED WATER 32PK', 0.34293630719184875), ('KALE BUNCH RPC', 0.3079712688922882), ('DASANI PURE WATER 24PK', 0.3035476803779602)]]
# 203629123
# []
# 276378441
# []
# 124846791
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5778824090957642), ('KALE BUNCH RPC', 0.5712507963180542), ('STO 2%RF MILK', 0.5544442534446716)]]
# 229011551
# []
# 260720985
# []
# 291076707
# []
# 116292638
# []
# 185107371
# []
# 340015723
# [[('KALE BUNCH RPC', 0.7184330224990845), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.7033437490463257), ('STO 2%RF MILK', 0.6746741533279419)], [('ICEBERG LETTUCE', 0.2603684663772583), ('DELI CKN FR SLF SRV 8P H', 0.25517693161964417), ('KRO 1%LF MILK', 0.21925628185272217)]]
# 226414084
# [[('KALE BUNCH RPC', 0.28890085220336914), ('MILLER LITE 24PK CAN', 0.2722713351249695), ('KRO 1% LF MILK', 0.2714674472808838)]]
# 240153865
# [[('KITKAT CRISP WAFER', 0.18309709429740906), ('DELI CKN FR SLF SRV 8P H', 0.1500629186630249), ('MILLER LITE 24PK CAN', 0.14767128229141235)]]
# 17392793
# []
# 129462039
# []
# 299205146
# [[('BUD LIGHT 24PK CAN', 0.4942016303539276), ('KALE BUNCH RPC', 0.4596514105796814), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.45333313941955566)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 100237874
# [[('BUD LIGHT 24PK CAN', 0.4054492712020874), ('KALE BUNCH RPC', 0.3748836815357208), ('STO 2%RF MILK', 0.3745972514152527)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 101887542
# [[('KALE BUNCH RPC', 0.2934151291847229), ('STO 2%RF MILK', 0.28568035364151), ('HMCTY ICE NUGGETS 22LB', 0.2849181890487671)]]
# 245786027
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 106751630
# []
# 147462153
# []
# 148132181
# [[('KALE BUNCH RPC', 0.7184330224990845), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.7033437490463257), ('STO 2%RF MILK', 0.6746741533279419)], [('KALE BUNCH RPC', 0.45346736907958984), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.447645902633667), ('DERPRK SPRING WATER 24PK', 0.423600435256958)]]
# 119194639
# []
# 95194213
# [[('DIET MTN DEW 12PK', 0.22819821536540985), ('DOLE BANANAS', 0.19578896462917328), ('KRO GNT 10RL PPR TWL ROLL', 0.1876983493566513)]]
# 300630621
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 146937577
# [[('KRO 1% LF MILK', 0.2506715655326843), ('COKE CLASSIC', 0.2387664020061493), ('BUD LIGHT 24PK CAN', 0.2380378693342209)]]
# 263107933
# []
# 104962874
# []
# 290772182
# []
# 244373580
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 321414171
# [[('ICE CRUSHED CUBED', 0.3891516327857971), ('DOLE BANANAS TAPED ORGNC', 0.27235695719718933), ('ICEBERG LETTUCE', 0.24126875400543213)]]
# 93109022
# [[('KALE BUNCH RPC', 0.8698782920837402), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.8689242601394653), ('STO 2%RF MILK', 0.812996506690979)], [('KALE BUNCH RPC', 0.7184330224990845), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.7033437490463257), ('STO 2%RF MILK', 0.6746741533279419)]]
# 93569215
# []
# 251936258
# [[('SNCKRS BAR', 0.20096398890018463), ('DERPRK SPRING WATER 24PK', 0.13142672181129456), ('KRO VITAMIN D WHOLE MILK', 0.1141682043671608)]]
# 253178360
# [[('BKRY SS DONUTS', 0.28376561403274536), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.25741779804229736), ('KRO PURIFIED WATER 32PK', 0.2542024850845337)]]
# 97463535
# [[('KRO HEAVY WHIPPING CREAM', 0.25994011759757996), ('BUD LIGHT 24PK CAN', 0.2513977885246277), ('DIET COKE 6PK', 0.21376897394657135)]]
# 296518649
# [[('KALE BUNCH RPC', 0.8698782920837402), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.8689242601394653), ('STO 2%RF MILK', 0.812996506690979)]]
# 335041167
# []
# 260367799
# []
# 99413710
# []
# 148531165
# []
# 190462690
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.6050950288772583), ('KALE BUNCH RPC', 0.599933922290802), ('BUD LIGHT 24PK CAN', 0.5908903479576111)], [('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 146815458
# []
# 335431332
# []
# 219315466
# []
# 146694812
# []
# 100055809
# []
# 93902000
# []
# 97204968
# []
# 102105036
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 147232696
# []
# 267060208
# [[('KALE BUNCH RPC', 0.5168688297271729), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.5123421549797058), ('KRO PURIFIED WATER 32PK', 0.46817290782928467)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.4988705515861511), ('BUD LIGHT 24PK CAN', 0.4734945595264435), ('STO 2%RF MILK', 0.4587148129940033)]]
# 320249421
# []
# 14595593
# []
# 123613844
# []
# 125607450
# [[('DOLE BANANAS TAPED ORGNC', 0.32175910472869873), ('BUD LIGHT 24PK CAN', 0.3027614653110504), ('KRO 30 DR BTH TSS', 0.29918035864830017)]]
# 146732292
# [[('DIET COKE 12PK', 0.2996777892112732), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.2644175589084625), ('STO 2%RF MILK', 0.26067110896110535)]]
# 189357355
# []
# 295130479
# []
# 224333740
# []
# 249058689
# []
# 148695259
# []
# 172256056
# [[('BUD LIGHT 24PK CAN', 0.4054492712020874), ('KALE BUNCH RPC', 0.3748836815357208), ('STO 2%RF MILK', 0.3745972514152527)], [('DIET COKE 12PK', 0.48909515142440796), ('BUD LIGHT 24PK CAN', 0.4245010018348694), ('KALE BUNCH RPC', 0.4238097667694092)]]
# 98602878
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 15353066
# [[('KALE BUNCH RPC', 0.28890085220336914), ('MILLER LITE 24PK CAN', 0.2722713351249695), ('KRO 1% LF MILK', 0.2714674472808838)]]
# 100030417
# []
# 328601729
# []
# 66459794
# []
# 247243256
# [[('KALE BUNCH RPC', 0.7184330224990845), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.7033437490463257), ('STO 2%RF MILK', 0.6746741533279419)]]
# 148021045
# []
# 147073466
# []
# 224334459
# [[('KRO PURIFIED WATER 32PK', 0.34293630719184875), ('KALE BUNCH RPC', 0.3079712688922882), ('DASANI PURE WATER 24PK', 0.3035476803779602)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.6050950288772583), ('KALE BUNCH RPC', 0.599933922290802), ('BUD LIGHT 24PK CAN', 0.5908903479576111)], [('BUD LIGHT 24PK CAN', 0.4942016303539276), ('KALE BUNCH RPC', 0.4596514105796814), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.45333313941955566)], [('KALE BUNCH RPC', 0.7184330224990845), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.7033437490463257), ('STO 2%RF MILK', 0.6746741533279419)]]
# 97753259
# []
# 255182189
# []
# 49665091
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 148854966
# [[('COKE ZERO', 0.43542152643203735), ('STO 2%RF MILK', 0.3702376186847687), ('DASANI PURE WATER 24PK', 0.34250926971435547)]]
# 306729064
# []
# 246121469
# []
# 111457126
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 342724967
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 92925323
# [[('COKE CLASSIC CONTOUR BTL', 0.280489057302475), ('KRO 30 DR BTH TSS', 0.27394306659698486), ('COKE ZERO', 0.24010296165943146)]]
# 107848896
# [[('KALE BUNCH RPC', 0.5986707806587219), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.5664805173873901), ('BUD LIGHT 24PK CAN', 0.5379250049591064)]]
# 127249844
# []
# 87897706
# [[('KRO HEAVY WHIPPING CREAM', 0.2864796817302704), ('STO 2%RF MILK', 0.2721879184246063), ('KALE BUNCH RPC', 0.26774534583091736)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)], [('KRO PURIFIED WATER 32PK', 0.34293630719184875), ('KALE BUNCH RPC', 0.3079712688922882), ('DASANI PURE WATER 24PK', 0.3035476803779602)]]
# 61265250
# []
# 98097152
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 339289922
# []
# 290732693
# []
# 1617300185
# []
# 272734518
# []
# 96108528
# [[('KALE BUNCH RPC', 0.5240429639816284), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4924411177635193), ('BUD LIGHT 24PK CAN', 0.47190362215042114)]]
# 100285709
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 340504888
# []
# 171763103
# [[('MILLER LITE 24PK CAN', 0.2669658064842224), ('KRO PURIFIED WATER 24PK', 0.26204556226730347), ('KITKAT CRISP WAFER', 0.2526586949825287)]]
# 147474265
# [[('KRO CIN REDS WATER', 0.26837825775146484), ('KRO 1%LF MILK', 0.26494812965393066), ('BH BQT MINUET', 0.26264122128486633)]]
# 101109395
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 264757373
# [[('COKE CLASSIC', 0.3199152648448944), ('STO 2%RF MILK', 0.31376686692237854), ('SAS GRAN SUGAR PLLT', 0.30172204971313477)]]
# 89659907
# [[('ICE CRUSHED CUBED', 0.27641263604164124), ('COKE CLASSIC', 0.23531830310821533), ('CTO BATH TISSUE', 0.17823508381843567)]]
# 149384827
# [[('COKE ZERO', 0.43542152643203735), ('STO 2%RF MILK', 0.3702376186847687), ('DASANI PURE WATER 24PK', 0.34250926971435547)]]
# 97477244
# []
# 147088897
# []
# 310053159
# [[('MILLER LITE 24PK CAN', 0.2669658064842224), ('KRO PURIFIED WATER 24PK', 0.26204556226730347), ('KITKAT CRISP WAFER', 0.2526586949825287)]]
# 147981885
# []
# 120219428
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 329034347
# []
# 100969764
# []
# 1881300090
# []
# 162644467
# [[('KALE BUNCH RPC', 0.45346736907958984), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.447645902633667), ('DERPRK SPRING WATER 24PK', 0.423600435256958)], [('KALE BUNCH RPC', 0.357295960187912), ('POST HNY BNCH OAT W/ALMND', 0.35685306787490845), ('DERPRK SPRING WATER 24PK', 0.33967921137809753)], [('BKRY SS DONUTS', 0.28376561403274536), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.25741779804229736), ('KRO PURIFIED WATER 32PK', 0.2542024850845337)]]
# 88996964
# [[('KRO 2% RF MILK', 0.1717262864112854), ('BFG VANILLA CLBRTN 6IN CK', 0.16423571109771729), ('KRO PURIFIED WATER 32PK', 0.15669207274913788)]]
# 195050879
# [[('KALE BUNCH RPC', 0.45346736907958984), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.447645902633667), ('DERPRK SPRING WATER 24PK', 0.423600435256958)], [('DIET COKE 12PK', 0.2996777892112732), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.2644175589084625), ('STO 2%RF MILK', 0.26067110896110535)]]
# 98548040
# [[('DIET COKE 12PK', 0.2996777892112732), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.2644175589084625), ('STO 2%RF MILK', 0.26067110896110535)]]
# 252264080
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.4599861204624176), ('KALE BUNCH RPC', 0.445765882730484), ('STO 2%RF MILK', 0.4221833348274231)], [('DIET COKE 12PK', 0.48909515142440796), ('BUD LIGHT 24PK CAN', 0.4245010018348694), ('KALE BUNCH RPC', 0.4238097667694092)]]
# 210978506
# []
# 12777498
# []
# 344210265
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 103797658
# []
# 262460750
# []
# 243415805
# []
# 329473860
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.4988705515861511), ('BUD LIGHT 24PK CAN', 0.4734945595264435), ('STO 2%RF MILK', 0.4587148129940033)]]
# 124583283
# [[('KALE BUNCH RPC', 0.28890085220336914), ('MILLER LITE 24PK CAN', 0.2722713351249695), ('KRO 1% LF MILK', 0.2714674472808838)]]
# 230335363
# []
# 129603621
# [[('RED BULL ENERGY DRINK', 0.30981314182281494), ('KALE BUNCH RPC', 0.27773433923721313), ('POST HNY BNCH OAT W/ALMND', 0.2626650929450989)], [('COKE CLASSIC', 0.4890950918197632), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4687293469905853), ('POST HNY BNCH OAT W/ALMND', 0.4420761466026306)], [('KALE BUNCH RPC', 0.46025264263153076), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4376057982444763), ('STO 2%RF MILK', 0.4360925257205963)]]
# 1755600192
# []
# 287520612
# []
# 17179857
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 118256266
# []
# 102473624
# []
# 137951352
# []
# 271400299
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 94989355
# [[('BKRY SS DONUTS', 0.28376561403274536), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.25741779804229736), ('KRO PURIFIED WATER 32PK', 0.2542024850845337)]]
# 289064033
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 256061888
# []
# 107594420
# []
# 310828998
# []
# 146528897
# []
# 329037245
# [[('COKE CLASSIC CONTOUR BTL', 0.280489057302475), ('KRO 30 DR BTH TSS', 0.27394306659698486), ('COKE ZERO', 0.24010296165943146)]]
# 147292235
# []
# 1097500068
# []
# 123803558
# [[('BKRY SS DONUTS', 0.28376561403274536), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.25741779804229736), ('KRO PURIFIED WATER 32PK', 0.2542024850845337)]]
# 93011765
# []
# 268347134
# [[('DELI SALAD BAR', 0.2921435832977295), ('KALE BUNCH RPC', 0.28445255756378174), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.27370527386665344)]]
# 784600100
# []
# 344611412
# []
# 102641569
# []
# 95828010
# []
# 87442666
# []
# 100428522
# []
# 148856282
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 92116314
# []
# 332386559
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 107194144
# []
# 125108039
# [[('KALE BUNCH RPC', 0.4285537898540497), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.3826340436935425), ('STO 2%RF MILK', 0.35212093591690063)]]
# 143175549
# []
# 187309106
# [[('DIET COKE 12PK', 0.20309126377105713), ('BH BQT HARMONY', 0.17082688212394714), ('KRO VITAMIN D WHOLE MILK', 0.16518577933311462)], [('SNCKRS BAR', 0.3891516327857971), ('CTO BATH TISSUE', 0.36832478642463684), ('KITKAT CRISP WAFER', 0.32578742504119873)]]
# 108152750
# []
# 95171713
# []
# 146802950
# []
# 107346418
# []
# 192134265
# []
# 126993307
# []
# 148052125
# []
# 250970349
# []
# 169468890
# []
# 121652000
# []
# 192798410
# []
# 158922758
# []
# 232450440
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)], [('MILLER LITE 24PK CAN', 0.2669658064842224), ('KRO PURIFIED WATER 24PK', 0.26204556226730347), ('KITKAT CRISP WAFER', 0.2526586949825287)]]
# 32247710
# [[('SNCKRS BAR', 0.20096398890018463), ('DERPRK SPRING WATER 24PK', 0.13142672181129456), ('KRO VITAMIN D WHOLE MILK', 0.1141682043671608)]]
# 122109160
# [[('KALE BUNCH RPC', 0.7184330224990845), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.7033437490463257), ('STO 2%RF MILK', 0.6746741533279419)]]
# 334199534
# [[('KALE BUNCH RPC', 0.8698782920837402), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.8689242601394653), ('STO 2%RF MILK', 0.812996506690979)]]
# 128237051
# []
# 7420205
# []
# 124577990
# [[('KRO PURIFIED WATER 32PK', 0.34293630719184875), ('KALE BUNCH RPC', 0.3079712688922882), ('DASANI PURE WATER 24PK', 0.3035476803779602)]]
# 91508862
# [[('COKE ZERO', 0.43542152643203735), ('STO 2%RF MILK', 0.3702376186847687), ('DASANI PURE WATER 24PK', 0.34250926971435547)], [('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 149446227
# [[('SAS GRAN SUGAR PLLT', 0.14673934876918793), ('KRO HEAVY WHIPPING CREAM', 0.14541704952716827), ('KRO DISTILLED WATER', 0.12362253665924072)]]
# 277107317
# []
# 233925530
# []
# 340429203
# []
# 290082003
# []
# 106911018
# []
# 180344700
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5778824090957642), ('KALE BUNCH RPC', 0.5712507963180542), ('STO 2%RF MILK', 0.5544442534446716)]]
# 212319294
# []
# 93854512
# []
# 258668591
# [[('KRO HEAVY WHIPPING CREAM', 0.25994011759757996), ('BUD LIGHT 24PK CAN', 0.2513977885246277), ('DIET COKE 6PK', 0.21376897394657135)]]
# 203919514
# []
# 259445720
# []
# 169500713
# []
# 97697728
# []
# 149190805
# []
# 101203757
# [[('KALE BUNCH RPC', 0.5986707806587219), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.5664805173873901), ('BUD LIGHT 24PK CAN', 0.5379250049591064)], [('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 146906017
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 341973270
# []
# 148198751
# []
# 125690935
# []
# 186494644
# []
# 166401458
# []
# 148750325
# [[('POST HNY BNCH OAT W/ALMND', 0.42829930782318115), ('DIET COKE 6PK', 0.3781619369983673), ('KALE BUNCH RPC', 0.3724890947341919)]]
# 148107395
# [[('KALE BUNCH RPC', 0.7184330224990845), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.7033437490463257), ('STO 2%RF MILK', 0.6746741533279419)]]
# 102242568
# [[('KRO 2% RF MILK', 0.21689674258232117), ('KRO 1% LF MILK', 0.21043917536735535), ('COKE CLASSIC 12PK', 0.20376767218112946)]]
# 92676280
# []
# 105180416
# []
# 96424204
# []
# 89385231
# []
# 225365376
# []
# 259713272
# []
# 149246708
# []
# 108382862
# []
# 331827942
# []
# 94759913
# [[('DOLE BANANAS TAPED ORGNC', 0.32175910472869873), ('BUD LIGHT 24PK CAN', 0.3027614653110504), ('KRO 30 DR BTH TSS', 0.29918035864830017)]]
# 266734557
# []
# 148358742
# []
# 13328189
# []
# 148138324
# []
# 93822014
# []
# 102711775
# []
# 329910920
# []
# 146831640
# []
# 329910887
# [[('ANGSFT BATH TISSUE DBL RL', 0.2864796817302704), ('KRO VITAMIN D WHOLE MILK', 0.25994011759757996), ('DIET COKE 12PK', 0.22594791650772095)]]
# 97652835
# []
# 259408581
# []
# 123158583
# [[('KALE BUNCH RPC', 0.33693283796310425), ('DOLE BANANAS', 0.3346328139305115), ('DELI SALAD BAR', 0.3334997594356537)]]
# 148068109
# []
# 197594266
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 200081273
# []
# 247243894
# []
# 147252002
# [[('KALE BUNCH RPC', 0.46195340156555176), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.45312488079071045), ('STO 2%RF MILK', 0.4478839635848999)]]
# 100938195
# []
# 74430848
# []
# 129938485
# [[('KRO HEAVY WHIPPING CREAM', 0.25994011759757996), ('BUD LIGHT 24PK CAN', 0.2513977885246277), ('DIET COKE 6PK', 0.21376897394657135)]]
# 242843286
# []
# 97681928
# [[('ICEBERG LETTUCE', 0.2603684663772583), ('DELI CKN FR SLF SRV 8P H', 0.25517693161964417), ('KRO 1%LF MILK', 0.21925628185272217)]]
# 104894182
# [[('KALE BUNCH RPC', 0.4285537898540497), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.3826340436935425), ('STO 2%RF MILK', 0.35212093591690063)], [('COKE ZERO', 0.43542152643203735), ('STO 2%RF MILK', 0.3702376186847687), ('DASANI PURE WATER 24PK', 0.34250926971435547)]]
# 274141903
# [[('ICE CRUSHED CUBED', 0.27641263604164124), ('COKE CLASSIC', 0.23531830310821533), ('CTO BATH TISSUE', 0.17823508381843567)]]
# 147999034
# []
# 129368054
# []
# 268673510
# [[('DOLE BANANAS TAPED ORGNC', 0.32175910472869873), ('BUD LIGHT 24PK CAN', 0.3027614653110504), ('KRO 30 DR BTH TSS', 0.29918035864830017)], [('DIET COKE 12PK', 0.48909515142440796), ('BUD LIGHT 24PK CAN', 0.4245010018348694), ('KALE BUNCH RPC', 0.4238097667694092)]]
# 261791948
# [[('KRO HEAVY WHIPPING CREAM', 0.25994011759757996), ('BUD LIGHT 24PK CAN', 0.2513977885246277), ('DIET COKE 6PK', 0.21376897394657135)]]
# 245217945
# []
# 294484536
# [[('STO 2%RF MILK', 0.4248989224433899), ('KALE BUNCH RPC', 0.4227912724018097), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4133933186531067)]]
# 106364659
# []
# 333208411
# [[('DOLE BANANAS TAPED ORGNC', 0.32175910472869873), ('BUD LIGHT 24PK CAN', 0.3027614653110504), ('KRO 30 DR BTH TSS', 0.29918035864830017)], [('KALE BUNCH RPC', 0.4894072413444519), ('STO 2%RF MILK', 0.46752282977104187), ('BUD LIGHT 24PK CAN', 0.4584292471408844)]]
# 271437809
# []
# 15427531
# []
# 223722176
# [[('RED BULL ENERGY DRINK', 0.30981314182281494), ('KALE BUNCH RPC', 0.27773433923721313), ('POST HNY BNCH OAT W/ALMND', 0.2626650929450989)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.4988705515861511), ('BUD LIGHT 24PK CAN', 0.4734945595264435), ('STO 2%RF MILK', 0.4587148129940033)]]
# 100600110
# []
# 55803090
# [[('POST HNY BNCH OAT W/ALMND', 0.42829930782318115), ('DIET COKE 6PK', 0.3781619369983673), ('KALE BUNCH RPC', 0.3724890947341919)]]
# 308847130
# []
# 328180802
# []
# 270467131
# [[('DELI SALAD BAR', 0.2921435832977295), ('KALE BUNCH RPC', 0.28445255756378174), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.27370527386665344)]]
# 101857474
# []
# 108841450
# []
# 50414378
# []
# 229545477
# []
# 127959562
# []
# 343115385
# [[('KRO PURIFIED WATER 32PK', 0.34293630719184875), ('KALE BUNCH RPC', 0.3079712688922882), ('DASANI PURE WATER 24PK', 0.3035476803779602)]]
# 149034788
# []
# 98618264
# []
# 104596323
# []
# 84969512
# []
# 315264907
# [[('MILLER LITE 24PK CAN', 0.2669658064842224), ('KRO PURIFIED WATER 24PK', 0.26204556226730347), ('KITKAT CRISP WAFER', 0.2526586949825287)]]
# 204012242
# []
# 270803792
# []
# 158720993
# []
# 147928719
# []
# 16534545
# []
# 148163403
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 147762524
# []
# 329906174
# []
# 149304669
# [[('COKE CLASSIC', 0.3199152648448944), ('STO 2%RF MILK', 0.31376686692237854), ('SAS GRAN SUGAR PLLT', 0.30172204971313477)], [('KALE BUNCH RPC', 0.46025264263153076), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4376057982444763), ('STO 2%RF MILK', 0.4360925257205963)]]
# 228994098
# []
# 320144137
# []
# 118180688
# []
# 216527574
# []
# 89615672
# [[('STO 2%RF MILK', 0.4248989224433899), ('KALE BUNCH RPC', 0.4227912724018097), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4133933186531067)]]
# 185690221
# []
# 127250815
# [[('KRO 2% RF MILK', 0.2402542680501938), ('KRO POTATOES IDAHO PREM', 0.2196442186832428), ('KRO PURIFIED WATER 24PK', 0.21184732019901276)]]
# 148185953
# [[('KRO 1% LF MILK', 0.2506715655326843), ('COKE CLASSIC', 0.2387664020061493), ('BUD LIGHT 24PK CAN', 0.2380378693342209)]]
# 326392182
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 102373490
# []
# 12682862
# []
# 246650171
# []
# 121045819
# []
# 273473861
# [[('KRO HEAVY WHIPPING CREAM', 0.25994011759757996), ('BUD LIGHT 24PK CAN', 0.2513977885246277), ('DIET COKE 6PK', 0.21376897394657135)]]
# 100166566
# []
# 102215954
# []
# 242226169
# []
# 245790468
# [[('KRO HEAVY WHIPPING CREAM', 0.2864796817302704), ('STO 2%RF MILK', 0.2721879184246063), ('KALE BUNCH RPC', 0.26774534583091736)]]
# 123331835
# []
# 120212125
# [[('KALE BUNCH RPC', 0.357295960187912), ('POST HNY BNCH OAT W/ALMND', 0.35685306787490845), ('DERPRK SPRING WATER 24PK', 0.33967921137809753)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)], [('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)], [('KALE BUNCH RPC', 0.5168688297271729), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.5123421549797058), ('KRO PURIFIED WATER 32PK', 0.46817290782928467)], [('KRO 2% RF MILK', 0.21689674258232117), ('KRO 1% LF MILK', 0.21043917536735535), ('COKE CLASSIC 12PK', 0.20376767218112946)]]
# 119850292
# []
# 149241246
# []
# 127043531
# []
# 147781139
# [[('KRO 1% LF MILK', 0.2506715655326843), ('COKE CLASSIC', 0.2387664020061493), ('BUD LIGHT 24PK CAN', 0.2380378693342209)], [('KALE BUNCH RPC', 0.46025264263153076), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4376057982444763), ('STO 2%RF MILK', 0.4360925257205963)]]
# 215038640
# []
# 216283009
# [[('SAS GRAN SUGAR PLLT', 0.14673934876918793), ('KRO HEAVY WHIPPING CREAM', 0.14541704952716827), ('KRO DISTILLED WATER', 0.12362253665924072)]]
# 129254143
# []
# 108334485
# []
# 146924531
# []
# 287555529
# []
# 243127836
# [[('KRO 2% RF MILK', 0.2402542680501938), ('KRO POTATOES IDAHO PREM', 0.2196442186832428), ('KRO PURIFIED WATER 24PK', 0.21184732019901276)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 146662421
# []
# 147996319
# [[('ANGSFT BATH TISSUE DBL RL', 0.2864796817302704), ('KRO VITAMIN D WHOLE MILK', 0.25994011759757996), ('DIET COKE 12PK', 0.22594791650772095)], [('KALE BUNCH RPC', 0.7184330224990845), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.7033437490463257), ('STO 2%RF MILK', 0.6746741533279419)]]
# 161591498
# []
# 186750665
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)], [('SNCKRS BAR', 0.3891516327857971), ('CTO BATH TISSUE', 0.36832478642463684), ('KITKAT CRISP WAFER', 0.32578742504119873)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.4988705515861511), ('BUD LIGHT 24PK CAN', 0.4734945595264435), ('STO 2%RF MILK', 0.4587148129940033)]]
# 346181039
# []
# 22247243
# [[('DOLE BANANAS TAPED ORGNC', 0.32175910472869873), ('BUD LIGHT 24PK CAN', 0.3027614653110504), ('KRO 30 DR BTH TSS', 0.29918035864830017)]]
# 1285900022
# []
# 146970465
# []
# 230499175
# []
# 96809834
# []
# 108389443
# []
# 147635434
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.4599861204624176), ('KALE BUNCH RPC', 0.445765882730484), ('STO 2%RF MILK', 0.4221833348274231)], [('POST HNY BNCH OAT W/ALMND', 0.42829930782318115), ('DIET COKE 6PK', 0.3781619369983673), ('KALE BUNCH RPC', 0.3724890947341919)]]
# 149120410
# []
# 260079969
# []
# 271115793
# [[('BUD LIGHT 24PK CAN', 0.5987051725387573), ('KALE BUNCH RPC', 0.5926470160484314), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.5899031162261963)]]
# 174826932
# []
# 61348811
# []
# 96507346
# [[('KALE BUNCH RPC', 0.5168688297271729), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.5123421549797058), ('KRO PURIFIED WATER 32PK', 0.46817290782928467)]]
# 256887145
# [[('KRO HEAVY WHIPPING CREAM', 0.25994011759757996), ('BUD LIGHT 24PK CAN', 0.2513977885246277), ('DIET COKE 6PK', 0.21376897394657135)]]
# 99656838
# [[('KRO PURIFIED WATER 24PK', 0.3870144486427307), ('DASANI PURE WATER 24PK', 0.3767983019351959), ('KALE BUNCH RPC', 0.3621307611465454)]]
# 99833200
# [[('RED BULL ENERGY DRINK', 0.30981314182281494), ('KALE BUNCH RPC', 0.27773433923721313), ('POST HNY BNCH OAT W/ALMND', 0.2626650929450989)]]
# 148723006
# []
# 248752715
# []
# 156270487
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5778824090957642), ('KALE BUNCH RPC', 0.5712507963180542), ('STO 2%RF MILK', 0.5544442534446716)]]
# 325057167
# []
# 346203889
# [[('KALE BUNCH RPC', 0.4285537898540497), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.3826340436935425), ('STO 2%RF MILK', 0.35212093591690063)]]
# 128767468
# []
# 147137483
# []
# 147074641
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.36689767241477966), ('KALE BUNCH RPC', 0.34272706508636475), ('STO 2%RF MILK', 0.3406410813331604)]]
# 169738177
# []
# 315610778
# []
# 65214404
# []
# 147212125
# []
# 189941921
# []
# 301914361
# []
# 329855547
# []
# 308787324
# []
# 1304300058
# []
# 147651273
# [[('KALE BUNCH RPC', 0.5240429639816284), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4924411177635193), ('BUD LIGHT 24PK CAN', 0.47190362215042114)], [('COKE CLASSIC CONTOUR BTL', 0.280489057302475), ('KRO 30 DR BTH TSS', 0.27394306659698486), ('COKE ZERO', 0.24010296165943146)]]
# 146915781
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 221444804
# [[('KALE BUNCH RPC', 0.7184330224990845), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.7033437490463257), ('STO 2%RF MILK', 0.6746741533279419)], [('DELI SALAD BAR', 0.2921435832977295), ('KALE BUNCH RPC', 0.28445255756378174), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.27370527386665344)]]
# 223764812
# []
# 14905714
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 266408328
# []
# 258294618
# []
# 47805012
# ...
# []
# 98786005
# []
# 242866054
# []
# 331193904
# [[('KRO 2% RF MILK', 0.21689674258232117), ('KRO 1% LF MILK', 0.21043917536735535), ('COKE CLASSIC 12PK', 0.20376767218112946)]]
# 128271926
# []
# 216527342
# [[('KRO 2% RF MILK', 0.21689674258232117), ('KRO 1% LF MILK', 0.21043917536735535), ('COKE CLASSIC 12PK', 0.20376767218112946)], [('KALE BUNCH RPC', 0.33693283796310425), ('DOLE BANANAS', 0.3346328139305115), ('DELI SALAD BAR', 0.3334997594356537)]]
# 35778876
# []
# 147684489
# []
# 334600869
# []
# 105216055
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 258677588
# []
# 208303223
# []
# 113680511
# []
# 301579404
# []
# 100270071
# [[('KALE BUNCH RPC', 0.4894072413444519), ('STO 2%RF MILK', 0.46752282977104187), ('BUD LIGHT 24PK CAN', 0.4584292471408844)]]
# 118699030
# [[('DIET COKE 12PK', 0.20309126377105713), ('BH BQT HARMONY', 0.17082688212394714), ('KRO VITAMIN D WHOLE MILK', 0.16518577933311462)]]
# 252269910
# [[('KALE BUNCH RPC', 0.6344715356826782), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.6291137337684631), ('POST HNY BNCH OAT W/ALMND', 0.5791609883308411)]]
# 101067470
# []
# 304379148
# []
# 204512316
# []
# 174827805
# []
# 303640094
# []
# 260075476
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.4599861204624176), ('KALE BUNCH RPC', 0.445765882730484), ('STO 2%RF MILK', 0.4221833348274231)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 258679053
# [[('KRO 2% RF MILK', 0.24820101261138916), ('ST PISTACHIOS TUBE', 0.18443842232227325), ('KRO POTATOES IDAHO PREM', 0.18127363920211792)]]
# 12551620
# []
# 105358913
# []
# 201402217
# []
# 95136138
# [[('KALE BUNCH RPC', 0.5168688297271729), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.5123421549797058), ('KRO PURIFIED WATER 32PK', 0.46817290782928467)]]
# 290772375
# []
# 105846720
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 100156710
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 298875991
# []
# 148225514
# []
# 91712249
# [[('KALE BUNCH RPC', 0.357295960187912), ('POST HNY BNCH OAT W/ALMND', 0.35685306787490845), ('DERPRK SPRING WATER 24PK', 0.33967921137809753)]]
# 235640267
# []
# 129764606
# []
# 164748698
# [[('STO 2%RF MILK', 0.4248989224433899), ('KALE BUNCH RPC', 0.4227912724018097), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4133933186531067)]]
# 1184500093
# []
# 325074834
# []
# 148102922
# []
# 309215329
# []
# 310448428
# []
# 127560704
# []
# 118708357
# []
# 149161377
# []
# 102715209
# [[('KALE BUNCH RPC', 0.7184330224990845), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.7033437490463257), ('STO 2%RF MILK', 0.6746741533279419)], [('KALE BUNCH RPC', 0.6249558329582214), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.6147710680961609), ('STO 2%RF MILK', 0.5822712182998657)]]
# 129955099
# []
# 256875369
# []
# 276406841
# []
# 149084433
# [[('ICE CRUSHED CUBED', 0.27641263604164124), ('COKE CLASSIC', 0.23531830310821533), ('CTO BATH TISSUE', 0.17823508381843567)], [('KALE BUNCH RPC', 0.7184330224990845), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.7033437490463257), ('STO 2%RF MILK', 0.6746741533279419)], [('KALE BUNCH RPC', 0.6249558329582214), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.6147710680961609), ('STO 2%RF MILK', 0.5822712182998657)]]
# 147161265
# []
# 247220717
# [[('COKE ZERO', 0.43542152643203735), ('STO 2%RF MILK', 0.3702376186847687), ('DASANI PURE WATER 24PK', 0.34250926971435547)]]
# 259751971
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 55069533
# [[('KALE BUNCH RPC', 0.28890085220336914), ('MILLER LITE 24PK CAN', 0.2722713351249695), ('KRO 1% LF MILK', 0.2714674472808838)], [('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 148902208
# []
# 98573056
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 94186954
# []
# 186755222
# [[('KRO HEAVY WHIPPING CREAM', 0.25994011759757996), ('BUD LIGHT 24PK CAN', 0.2513977885246277), ('DIET COKE 6PK', 0.21376897394657135)], [('ICEBERG LETTUCE', 0.2603684663772583), ('DELI CKN FR SLF SRV 8P H', 0.25517693161964417), ('KRO 1%LF MILK', 0.21925628185272217)]]
# 148523583
# [[('DOLE BANANAS TAPED ORGNC', 0.32175910472869873), ('BUD LIGHT 24PK CAN', 0.3027614653110504), ('KRO 30 DR BTH TSS', 0.29918035864830017)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.36689767241477966), ('KALE BUNCH RPC', 0.34272706508636475), ('STO 2%RF MILK', 0.3406410813331604)], [('BUD LIGHT 24PK CAN', 0.36111050844192505), ('KRO PURIFIED WATER 32PK', 0.3399185538291931), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.33530083298683167)]]
# 127263729
# []
# 148376640
# []
# 89127916
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 334645517
# [[('KRO 2% RF MILK', 0.1717262864112854), ('BFG VANILLA CLBRTN 6IN CK', 0.16423571109771729), ('KRO PURIFIED WATER 32PK', 0.15669207274913788)]]
# 246393117
# []
# 147826599
# [[('SNCKRS BAR', 0.3891516327857971), ('CTO BATH TISSUE', 0.36832478642463684), ('KITKAT CRISP WAFER', 0.32578742504119873)]]
# 95954814
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 149243012
# []
# 297136408
# []
# 163170278
# [[('BUD LIGHT 24PK CAN', 0.4942016303539276), ('KALE BUNCH RPC', 0.4596514105796814), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.45333313941955566)]]
# 314929201
# [[('KRO PURIFIED WATER 32PK', 0.34293630719184875), ('KALE BUNCH RPC', 0.3079712688922882), ('DASANI PURE WATER 24PK', 0.3035476803779602)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 203634936
# []
# 95998099
# []
# 104945485
# []
# 128066127
# []
# 98680150
# [[('ICE CRUSHED CUBED', 0.3891516327857971), ('DOLE BANANAS TAPED ORGNC', 0.27235695719718933), ('ICEBERG LETTUCE', 0.24126875400543213)]]
# 217255243
# [[('KALE BUNCH RPC', 0.4285537898540497), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.3826340436935425), ('STO 2%RF MILK', 0.35212093591690063)]]
# 148747244
# []
# 335032988
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.4599861204624176), ('KALE BUNCH RPC', 0.445765882730484), ('STO 2%RF MILK', 0.4221833348274231)], [('KALE BUNCH RPC', 0.4894072413444519), ('STO 2%RF MILK', 0.46752282977104187), ('BUD LIGHT 24PK CAN', 0.4584292471408844)]]
# 217226092
# [[('KALE BUNCH RPC', 0.8698782920837402), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.8689242601394653), ('STO 2%RF MILK', 0.812996506690979)]]
# 200920785
# []
# 149145062
# []
# 185427655
# [[('KALE BUNCH RPC', 0.33693283796310425), ('DOLE BANANAS', 0.3346328139305115), ('DELI SALAD BAR', 0.3334997594356537)]]
# 147578946
# []
# 310806126
# []
# 147063219
# []
# 219318094
# []
# 295787398
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)]]
# 103496325
# []
# 201424596
# []
# 132063262
# []
# 227178908
# [[('BUD LIGHT 24PK CAN', 0.36111050844192505), ('KRO PURIFIED WATER 32PK', 0.3399185538291931), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.33530083298683167)]]
# 108131684
# []
# 149035153
# []
# 15327841
# []
# 107472101
# [[('DIET MTN DEW 12PK', 0.22819821536540985), ('DOLE BANANAS', 0.19578896462917328), ('KRO GNT 10RL PPR TWL ROLL', 0.1876983493566513)]]
# 203079647
# [[('KRO 2% RF MILK', 0.21689674258232117), ('KRO 1% LF MILK', 0.21043917536735535), ('COKE CLASSIC 12PK', 0.20376767218112946)], [('BUD LIGHT 24PK CAN', 0.4942016303539276), ('KALE BUNCH RPC', 0.4596514105796814), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.45333313941955566)]]
# 208284233
# [[('KRO 2% RF MILK', 0.24820101261138916), ('ST PISTACHIOS TUBE', 0.18443842232227325), ('KRO POTATOES IDAHO PREM', 0.18127363920211792)], [('KALE BUNCH RPC', 0.4894072413444519), ('STO 2%RF MILK', 0.46752282977104187), ('BUD LIGHT 24PK CAN', 0.4584292471408844)]]
# 102656565
# []
# 138760562
# []
# 107966864
# []
# 146662654
# []
# 147164522
# []
# 147945890
# []
# 293457056
# []
# 147082633
# []
# 148046470
# [[('COKE CLASSIC', 0.4890950918197632), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4687293469905853), ('POST HNY BNCH OAT W/ALMND', 0.4420761466026306)]]
# 317770830
# []
# 17467195
# []
# 148616325
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.4988705515861511), ('BUD LIGHT 24PK CAN', 0.4734945595264435), ('STO 2%RF MILK', 0.4587148129940033)], [('BKRY SS DONUTS', 0.28376561403274536), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.25741779804229736), ('KRO PURIFIED WATER 32PK', 0.2542024850845337)]]
# 206199531
# []
# 101028853
# [[('DELI SALAD BAR', 0.2921435832977295), ('KALE BUNCH RPC', 0.28445255756378174), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.27370527386665344)]]
# 298506732
# []
# 10483802
# []
# 202517164
# [[('KRO PURIFIED WATER 32PK', 0.34293630719184875), ('KALE BUNCH RPC', 0.3079712688922882), ('DASANI PURE WATER 24PK', 0.3035476803779602)]]
# 149197160
# [[('KRO PURIFIED WATER 24PK', 0.3870144486427307), ('DASANI PURE WATER 24PK', 0.3767983019351959), ('KALE BUNCH RPC', 0.3621307611465454)]]
# 146595550
# [[('KALE BUNCH RPC', 0.6249558329582214), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.6147710680961609), ('STO 2%RF MILK', 0.5822712182998657)]]
# 103512900
# []
# 97514036
# [[('BUD LIGHT 24PK CAN', 0.5987051725387573), ('KALE BUNCH RPC', 0.5926470160484314), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.5899031162261963)]]
# 148981320
# []
# 148615435
# []
# 148601257
# []
# 149230126
# []
# 147332472
# []
# 345846428
# []
# 102059055
# []
# 101870779
# [[('COKE CLASSIC', 0.4890950918197632), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4687293469905853), ('POST HNY BNCH OAT W/ALMND', 0.4420761466026306)]]
# 111302398
# []
# 332802827
# [[('DIET COKE 12PK', 0.20309126377105713), ('BH BQT HARMONY', 0.17082688212394714), ('KRO VITAMIN D WHOLE MILK', 0.16518577933311462)]]
# 94147305
# []
# 89591315
# [[('ICEBERG LETTUCE', 0.2603684663772583), ('DELI CKN FR SLF SRV 8P H', 0.25517693161964417), ('KRO 1%LF MILK', 0.21925628185272217)]]
# 158086855
# [[('BUD LIGHT 24PK CAN', 0.5987051725387573), ('KALE BUNCH RPC', 0.5926470160484314), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.5899031162261963)]]
# 314197711
# []
# 312694501
# []
# 15504528
# []
# 94943371
# []
# 192136490
# []
# 149108569
# []
# 129961090
# [[('KALE BUNCH RPC', 0.33693283796310425), ('DOLE BANANAS', 0.3346328139305115), ('DELI SALAD BAR', 0.3334997594356537)]]
# 98664220
# []
# 101835823
# []
# 147005423
# []
# 106624150
# []
# 132918430
# []
# 264114235
# [[('MILLER LITE 24PK CAN', 0.2669658064842224), ('KRO PURIFIED WATER 24PK', 0.26204556226730347), ('KITKAT CRISP WAFER', 0.2526586949825287)]]
# 108497652
# []
# 340073302
# []
# 149400313
# []
# 300252806
# [[('KALE BUNCH RPC', 0.6344715356826782), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.6291137337684631), ('POST HNY BNCH OAT W/ALMND', 0.5791609883308411)]]
# 271118585
# []
# 215547576
# []
# 189940620
# []
# 148571224
# [[('ICEBERG LETTUCE', 0.2603684663772583), ('DELI CKN FR SLF SRV 8P H', 0.25517693161964417), ('KRO 1%LF MILK', 0.21925628185272217)], [('KALE BUNCH RPC', 0.46025264263153076), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4376057982444763), ('STO 2%RF MILK', 0.4360925257205963)]]
# 147747424
# []
# 297850641
# []
# 15556087
# []
# 333857191
# [[('BUD LIGHT 24PK CAN', 0.36111050844192505), ('KRO PURIFIED WATER 32PK', 0.3399185538291931), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.33530083298683167)], [('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 209922189
# []
# 174852525
# []
# 129646926
# []
# 204505110
# []
# 337812694
# [[('SNCKRS BAR', 0.3891516327857971), ('CTO BATH TISSUE', 0.36832478642463684), ('KITKAT CRISP WAFER', 0.32578742504119873)]]
# 329910667
# [[('KALE BUNCH RPC', 0.7184330224990845), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.7033437490463257), ('STO 2%RF MILK', 0.6746741533279419)]]
# 257299263
# []
# 269313425
# []
# 184842891
# [[('KRO 2% RF MILK', 0.24820101261138916), ('ST PISTACHIOS TUBE', 0.18443842232227325), ('KRO POTATOES IDAHO PREM', 0.18127363920211792)]]
# 341980390
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)], [('KALE BUNCH RPC', 0.4894072413444519), ('STO 2%RF MILK', 0.46752282977104187), ('BUD LIGHT 24PK CAN', 0.4584292471408844)], [('KRO PURIFIED WATER 32PK', 0.2664624750614166), ('DIET COKE 12PK', 0.26443296670913696), ('BHAUS ROSE BUNCH LS COLOR', 0.24772271513938904)]]
# 329913126
# []
# 125189926
# []
# 120931388
# []
# 249385432
# [[('KRO 2% RF MILK', 0.21689674258232117), ('KRO 1% LF MILK', 0.21043917536735535), ('COKE CLASSIC 12PK', 0.20376767218112946)]]
# 14643480
# []
# 101473575
# []
# 340082625
# []
# 325547821
# []
# 97763949
# []
# 15740081
# []
# 266376553
# [[('KRO 2% RF MILK', 0.1717262864112854), ('BFG VANILLA CLBRTN 6IN CK', 0.16423571109771729), ('KRO PURIFIED WATER 32PK', 0.15669207274913788)], [('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 120633141
# [[('STO 2%RF MILK', 0.4248989224433899), ('KALE BUNCH RPC', 0.4227912724018097), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4133933186531067)], [('DIET COKE 12PK', 0.48909515142440796), ('BUD LIGHT 24PK CAN', 0.4245010018348694), ('KALE BUNCH RPC', 0.4238097667694092)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 173074697
# []
# 294484845
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.684607207775116), ('KALE BUNCH RPC', 0.6784859895706177), ('STO 2%RF MILK', 0.6488761305809021)], [('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 319884989
# []
# 244035019
# []
# 123858091
# []
# 108728590
# []
# 147172384
# []
# 172264218
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.6573269367218018), ('KALE BUNCH RPC', 0.6572238206863403), ('STO 2%RF MILK', 0.6259320974349976)]]
# 111941101
# []
# 125537466
# []
# 100644846
# [[('KRO 2% RF MILK', 0.21689674258232117), ('KRO 1% LF MILK', 0.21043917536735535), ('COKE CLASSIC 12PK', 0.20376767218112946)]]
# 216887127
# []
# 122268942
# []
# 146949994
# []
# 108747864
# []
# 149063763
# []
# 93295417
# []
# 148530160
# []
# 328184405
# []
# 187862110
# []
# 76590745
# []
# 147717919
# []
# 14646843
# [[('BUD LIGHT 24PK CAN', 0.4054492712020874), ('KALE BUNCH RPC', 0.3748836815357208), ('STO 2%RF MILK', 0.3745972514152527)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)], [('KALE BUNCH RPC', 0.46025264263153076), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.4376057982444763), ('STO 2%RF MILK', 0.4360925257205963)]]
# 252883726
# []
# 105713488
# [[('ANGSFT BATH TISSUE DBL RL', 0.2864796817302704), ('KRO VITAMIN D WHOLE MILK', 0.25994011759757996), ('DIET COKE 12PK', 0.22594791650772095)], [('KALE BUNCH RPC,KALE BUNCH RPC', 0.5202544927597046), ('KALE BUNCH RPC', 0.492653489112854), ('BUD LIGHT 24PK CAN', 0.476080983877182)], [('ICE CRUSHED CUBED', 0.27641263604164124), ('COKE CLASSIC', 0.23531830310821533), ('CTO BATH TISSUE', 0.17823508381843567)], [('KRO HEAVY WHIPPING CREAM', 0.25994011759757996), ('BUD LIGHT 24PK CAN', 0.2513977885246277), ('DIET COKE 6PK', 0.21376897394657135)]]
# 98969274
# []
# 91904487
# [[('KALE BUNCH RPC,KALE BUNCH RPC', 0.9579091668128967), ('STO 2%RF MILK', 0.9059560894966125), ('BUD LIGHT 24PK CAN', 0.8698781728744507)]]
# 195814465
# [[('KRO HEAVY WHIPPING CREAM', 0.25994011759757996), ('BUD LIGHT 24PK CAN', 0.2513977885246277), ('DIET COKE 6PK', 0.21376897394657135)]]
# 319535753
# []
# 200920724
# [[('KRO 2% RF MILK', 0.2402542680501938), ('KRO POTATOES IDAHO PREM', 0.2196442186832428), ('KRO PURIFIED WATER 24PK', 0.21184732019901276)], [('KALE BUNCH RPC', 0.45346736907958984), ('KALE BUNCH RPC,KALE BUNCH RPC', 0.447645902633667), ('DERPRK SPRING WATER 24PK', 0.423600435256958)]]
# 330766351
# []
# 202796551
# []
# 122092236
# []
# 294449043
# []
# 149263171
# []
# 104319685
# []
# 149422764
# []
# 146617502
# []
# 146769909
# []
# 94629874
# []
# 100539082
# []
# 288708341
# []
# 96735292
# [[('STO 2%RF MILK', 0.439344584941864), ('KALE BUNCH RPC', 0.4346727430820465), ('CTO BATH TISSUE', 0.4201456606388092)]]
# 149016375
# []
# 201462277
# []
